# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %%
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Example
vocabulary[0:9]
# Out:
# Data size 17005207
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

# %%
def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# %%
## Of note, this operation is thread-bound :|
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.

# %%
print('Most common words (+UNK)', count[:5])
print()
print('Sample data: ', data[:10])
print('Reverse Dictionary: ', [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
#
# Sample data:  [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# Reverse Dictionary:  ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

# %%
# Interesting!
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8): print(batch[i], reverse_dictionary[batch[i]],'->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 5239 anarchism
# 3084 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3084 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# %%
# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

# %%
### TF Graph ###
graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  300.275024414
# Nearest to seven: nachrichten, weymouth, congregationalist, castro, verbose, slates, epistolary, rabbinic,
# Nearest to from: pregnancies, malwa, nicolay, deadlines, endomorphisms, aug, pictish, mentats,
# Nearest to other: hala, authored, treacherous, desktops, variation, telegraphs, kinetics, galilean,
# Nearest to d: bulky, onslaught, pagos, heures, laurents, cornelis, enroll, supercharger,
# Nearest to to: scientists, gustaf, diu, middlesbrough, families, bixby, hler, leveling,
# Nearest to four: cultures, rushdie, persson, eminence, realistically, bartolom, praetorians, imr,
# Nearest to been: trivalent, carlist, ferrigno, inexact, myrna, toomer, richness, disappearing,
# Nearest to there: amphetamine, doors, dealer, proprietary, hwa, szl, dimensionally, nugget,
# Nearest to called: ringed, malaysia, isabelle, mazzola, zuma, eagles, low, survivors,
# Nearest to this: tachycardia, shunned, training, warren, bonham, kullervo, immunology, koffice,
# Nearest to after: ethel, montrose, finished, cosmology, firewalls, shuja, micromachining, tributes,
# Nearest to known: hander, latina, hol, tatian, ranging, wallenberg, passive, fortress,
# Nearest to may: acres, projective, golfer, byline, deism, theorized, collectives, koran,
# Nearest to and: ruled, kinship, purse, quarrels, bauhaus, counted, fie, fourteenth,
# Nearest to have: archaeoastronomy, daemon, salim, posture, fulfil, reminiscent, zech, osamu,
# Nearest to first: henriette, knud, opacity, pinyin, chariot, miller, gianfranco, il,
# Average loss at step  2000 :  113.510675904
# Average loss at step  4000 :  53.218103806
# Average loss at step  6000 :  32.6966701562
# Average loss at step  8000 :  23.2985073133
# Average loss at step  10000 :  18.0479657686
# Nearest to seven: nine, zero, archie, solf, six, forth, vs, one,
# Nearest to from: and, in, pregnancies, of, by, depictions, efforts, dickinson,
# Nearest to other: variation, the, phi, theories, influenced, proclaim, in, performed,
# Nearest to d: anesthesia, gland, australian, peikoff, consonant, moved, rival, homes,
# Nearest to to: and, in, omega, scientists, for, content, mya, of,
# Nearest to four: nine, zero, agave, two, six, phi, one, five,
# Nearest to been: handing, angola, oman, fire, holocaust, accumulation, todd, chamber,
# Nearest to there: a, rearden, gland, proprietary, doors, hakama, antimatter, solution,
# Nearest to called: borough, tao, low, malaysia, survivors, vs, UNK, this,
# Nearest to this: borough, the, a, shunned, armies, UNK, milne, which,
# Nearest to after: weak, finished, opposed, cosmology, joints, changing, entities, dystopian,
# Nearest to known: mathbf, archive, solve, altenberg, substance, develop, translate, photographed,
# Nearest to may: acres, ada, coke, punishment, golfer, oval, var, deism,
# Nearest to and: in, of, UNK, the, agave, with, or, from,
# Nearest to have: be, scottish, had, mathbf, hakama, plus, and, cardinality,
# Nearest to first: reorganized, in, two, elementary, fetus, ironically, il, ideals,
# Average loss at step  12000 :  14.3337463156
# Average loss at step  14000 :  11.6695807724
# Average loss at step  16000 :  9.92294521153
# Average loss at step  18000 :  8.45565187812
# Average loss at step  20000 :  8.18943497121
# Nearest to seven: nine, zero, six, five, eight, three, four, operatorname,
# Nearest to from: in, by, and, of, agouti, for, pregnancies, fe,
# Nearest to other: variation, shirkuh, influenced, tries, threonine, theories, phi, batll,
# Nearest to d: b, australian, and, anesthesia, homes, consonant, rival, circ,
# Nearest to to: and, operatorname, omega, for, in, mya, agouti, content,
# Nearest to four: nine, six, zero, five, eight, two, three, seven,
# Nearest to been: was, handing, is, cavities, be, angola, who, oman,
# Nearest to there: it, they, rearden, gland, operatorname, proprietary, doors, which,
# Nearest to called: tao, survivors, borough, malaysia, low, operatorname, UNK, too,
# Nearest to this: the, a, which, operatorname, borough, it, warren, circ,
# Nearest to after: weak, ethel, of, and, agouti, scientifically, alexandrovna, joints,
# Nearest to known: mathbf, antibody, translate, solve, cultivate, archive, substance, customary,
# Nearest to may: acres, golfer, would, can, punishment, six, will, did,
# Nearest to and: or, agouti, in, operatorname, of, zero, batll, dasyprocta,
# Nearest to have: be, had, fortunate, and, agouti, plus, scottish, is,
# Nearest to first: reorganized, UNK, in, carved, henriette, appendicitis, fetus, ironically,
# Average loss at step  22000 :  7.04066575181
# Average loss at step  24000 :  6.86211717689
# Average loss at step  26000 :  6.8869371134
# Average loss at step  28000 :  6.36338955903
# Average loss at step  30000 :  5.97171968114
# Nearest to seven: nine, six, eight, four, five, zero, three, operatorname,
# Nearest to from: by, in, and, agouti, on, into, for, of,
# Nearest to other: variation, shirkuh, tries, phi, threonine, batll, percy, inhabiting,
# Nearest to d: b, and, australian, birkenau, anesthesia, consonant, circ, homes,
# Nearest to to: operatorname, eight, mya, and, for, nine, will, into,
# Nearest to four: six, eight, five, seven, two, three, zero, nine,
# Nearest to been: mishnayot, was, be, by, handing, were, cavities, also,
# Nearest to there: it, they, which, operatorname, rearden, still, gland, mishnayot,
# Nearest to called: and, tao, isabelle, ringed, borough, survivors, malaysia, aba,
# Nearest to this: which, the, it, a, operatorname, each, that, one,
# Nearest to after: ethel, in, shuja, when, and, of, three, scientifically,
# Nearest to known: translate, arin, antibody, mathbf, chipset, solve, cultivate, customary,
# Nearest to may: acres, can, would, will, projective, cannot, golfer, must,
# Nearest to and: or, agouti, operatorname, dasyprocta, zero, in, batll, of,
# Nearest to have: had, be, are, has, were, agouti, plus, compatibility,
# Nearest to first: reorganized, in, carved, four, appendicitis, coffee, henriette, same,
# Average loss at step  32000 :  5.98797777426
# Average loss at step  34000 :  5.67380944538
# Average loss at step  36000 :  5.83995612252
# Average loss at step  38000 :  5.50595944083
# Average loss at step  40000 :  5.2725629164
# Nearest to seven: six, eight, five, four, nine, three, zero, one,
# Nearest to from: in, by, zero, into, on, agouti, and, batll,
# Nearest to other: zero, variation, shirkuh, hendrik, phi, threonine, tries, batll,
# Nearest to d: b, australian, laurents, expedition, birkenau, consonant, and, anesthesia,
# Nearest to to: zero, operatorname, mya, will, agouti, for, undermined, into,
# Nearest to four: five, six, three, eight, seven, zero, two, one,
# Nearest to been: was, be, mishnayot, were, by, handing, also, had,
# Nearest to there: it, they, which, still, he, gland, zero, rearden,
# Nearest to called: and, tao, zero, ringed, isabelle, borough, survivors, aba,
# Nearest to this: which, it, the, that, each, zero, a, operatorname,
# Nearest to after: ethel, when, scientifically, shuja, before, since, zero, in,
# Nearest to known: translate, such, antibody, chipset, tatian, customary, arin, just,
# Nearest to may: can, would, acres, will, must, cannot, zero, projective,
# Nearest to and: or, zero, agouti, in, operatorname, but, dasyprocta, batll,
# Nearest to have: had, be, has, are, were, zero, agouti, plus,
# Nearest to first: zero, reorganized, carved, coffee, four, same, appendicitis, pinyin,
# Average loss at step  42000 :  5.37985967863
# Average loss at step  44000 :  5.23566290212
# Average loss at step  46000 :  5.24724727535
# Average loss at step  48000 :  5.22654915273
# Average loss at step  50000 :  5.0053332175
# Nearest to seven: six, eight, five, four, three, nine, zero, operatorname,
# Nearest to from: in, into, by, and, agouti, of, on, for,
# Nearest to other: some, various, hendrik, politically, batll, several, midwest, two,
# Nearest to d: b, and, australian, expedition, birkenau, circ, anesthesia, consonant,
# Nearest to to: will, mya, and, nine, operatorname, undermined, can, must,
# Nearest to four: six, five, three, eight, seven, two, one, zero,
# Nearest to been: be, was, mishnayot, by, were, also, handing, had,
# Nearest to there: it, they, johansen, still, he, which, gland, operatorname,
# Nearest to called: and, tao, ringed, operatorname, besieged, aba, temporal, dasyprocta,
# Nearest to this: which, it, the, that, each, kapoor, a, operatorname,
# Nearest to after: when, before, ethel, weak, in, since, four, three,
# Nearest to known: tatian, translate, such, just, antibody, arin, chipset, customary,
# Nearest to may: can, would, will, must, acres, cannot, liao, should,
# Nearest to and: or, but, agouti, operatorname, four, six, five, dasyprocta,
# Nearest to have: had, be, are, has, were, compatibility, agouti, abakan,
# Nearest to first: four, same, carved, reorganized, altenberg, appendicitis, antiprism, fetus,
# Average loss at step  52000 :  5.03266222072
# Average loss at step  54000 :  5.20781227338
# Average loss at step  56000 :  5.03695588148
# Average loss at step  58000 :  5.03450389767
# Average loss at step  60000 :  4.95464631367
# Nearest to seven: eight, six, five, nine, four, three, zero, wct,
# Nearest to from: into, in, agouti, by, on, and, ursus, pulau,
# Nearest to other: some, various, several, these, many, hendrik, two, thibetanus,
# Nearest to d: b, expedition, wct, australian, birkenau, circ, decius, yahweh,
# Nearest to to: operatorname, will, can, mya, entertainments, wct, nine, for,
# Nearest to four: five, six, three, eight, seven, two, nine, michelob,
# Nearest to been: be, was, mishnayot, by, were, had, already, handing,
# Nearest to there: it, they, still, johansen, he, which, this, gland,
# Nearest to called: and, tao, ringed, besieged, temporal, englishman, aba, isabelle,
# Nearest to this: which, it, that, the, kapoor, each, operatorname, one,
# Nearest to after: when, before, since, in, from, three, agouti, if,
# Nearest to known: tatian, such, translate, just, customary, antibody, chipset, arin,
# Nearest to may: can, would, will, must, acres, cannot, should, liao,
# Nearest to and: or, wct, but, operatorname, batll, agouti, ursus, dasyprocta,
# Nearest to have: had, has, are, be, were, johansen, michelob, agouti,
# Nearest to first: same, michelob, four, carved, altenberg, agrarian, reorganized, linebackers,
# Average loss at step  62000 :  5.03405175006
# Average loss at step  64000 :  4.84005017382
# Average loss at step  66000 :  4.60664907241
# Average loss at step  68000 :  5.00021466017
# Average loss at step  70000 :  4.90953506804
# Nearest to seven: eight, six, four, five, nine, three, zero, wct,
# Nearest to from: into, in, agouti, by, on, through, and, ursus,
# Nearest to other: some, many, several, these, various, others, hendrik, scripture,
# Nearest to d: b, cebus, expedition, wct, circ, decius, yahweh, birkenau,
# Nearest to to: operatorname, will, upanija, can, mya, would, undermined, wct,
# Nearest to four: six, five, three, eight, seven, two, nine, michelob,
# Nearest to been: be, was, were, mishnayot, by, had, already, handing,
# Nearest to there: it, they, still, johansen, he, which, this, gland,
# Nearest to called: and, tao, microcebus, ringed, besieged, englishman, temporal, aba,
# Nearest to this: which, it, the, that, kapoor, each, operatorname, lesion,
# Nearest to after: when, before, since, if, weak, agouti, during, upanija,
# Nearest to known: tatian, such, used, translate, just, customary, well, antibody,
# Nearest to may: can, would, will, must, cannot, acres, should, might,
# Nearest to and: or, upanija, but, agouti, wct, cebus, microcebus, operatorname,
# Nearest to have: had, has, were, are, be, johansen, abakan, michelob,
# Nearest to first: same, clo, michelob, carved, thaler, bunny, last, four,
# Average loss at step  72000 :  4.74809843814
# Average loss at step  74000 :  4.79096588635
# Average loss at step  76000 :  4.70061342752
# Average loss at step  78000 :  4.80391665637
# Average loss at step  80000 :  4.79997853941
# Nearest to seven: six, eight, five, four, nine, three, zero, one,
# Nearest to from: into, in, through, by, during, agouti, on, pulau,
# Nearest to other: some, many, various, these, several, others, including, scripture,
# Nearest to d: b, cebus, expedition, wct, circ, birkenau, UNK, yahweh,
# Nearest to to: mya, operatorname, upanija, wct, will, undermined, mitral, must,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to been: be, were, was, mishnayot, by, had, already, vacuole,
# Nearest to there: it, they, still, he, johansen, which, this, usually,
# Nearest to called: and, microcebus, tao, besieged, ringed, temporal, englishman, dasyprocta,
# Nearest to this: which, it, that, the, kapoor, operatorname, there, each,
# Nearest to after: before, when, since, during, if, from, in, weak,
# Nearest to known: such, tatian, used, just, translate, customary, well, antibody,
# Nearest to may: can, would, will, must, cannot, should, might, acres,
# Nearest to and: or, but, upanija, wct, agouti, microcebus, operatorname, cebus,
# Nearest to have: had, has, were, are, be, abakan, nine, leased,
# Nearest to first: same, clo, last, second, michelob, bunny, carved, thaler,
# Average loss at step  82000 :  4.76179468393
# Average loss at step  84000 :  4.7670143348
# Average loss at step  86000 :  4.7582041198
# Average loss at step  88000 :  4.74535442674
# Average loss at step  90000 :  4.74138645363
# Nearest to seven: eight, five, six, four, nine, three, zero, wct,
# Nearest to from: into, in, by, through, during, agouti, ursus, pulau,
# Nearest to other: some, various, many, others, these, including, several, scripture,
# Nearest to d: b, cebus, expedition, f, UNK, circ, wct, onslaught,
# Nearest to to: operatorname, will, can, upanija, must, would, wct, mya,
# Nearest to four: five, seven, three, six, eight, two, nine, wct,
# Nearest to been: be, was, were, mishnayot, by, already, had, vacuole,
# Nearest to there: they, it, still, he, johansen, which, often, but,
# Nearest to called: and, microcebus, tao, dasyprocta, besieged, cebus, operatorname, temporal,
# Nearest to this: which, it, the, that, kapoor, operatorname, each, lesion,
# Nearest to after: before, when, during, since, if, from, courageous, by,
# Nearest to known: such, used, tatian, well, carnatic, customary, translate, just,
# Nearest to may: can, would, will, must, cannot, should, might, could,
# Nearest to and: or, but, upanija, cebus, wct, agouti, microcebus, operatorname,
# Nearest to have: had, has, were, are, be, abakan, johansen, nine,
# Nearest to first: same, peacocks, last, second, bunny, clo, thaler, michelob,
# Average loss at step  92000 :  4.66283260715
# Average loss at step  94000 :  4.73431008267
# Average loss at step  96000 :  4.68711578238
# Average loss at step  98000 :  4.59763394678
# Average loss at step  100000 :  4.70671073508
# Nearest to seven: six, eight, five, four, nine, three, zero, michelob,
# Nearest to from: into, in, through, agouti, during, ursus, leontopithecus, by,
# Nearest to other: some, various, including, many, these, others, several, dmd,
# Nearest to d: b, cebus, circ, wct, expedition, six, clo, birkenau,
# Nearest to to: operatorname, will, upanija, mya, must, can, wct, eight,
# Nearest to four: five, seven, three, six, eight, two, zero, michelob,
# Nearest to been: be, was, were, mishnayot, by, already, had, vacuole,
# Nearest to there: they, it, he, still, johansen, often, this, operatorname,
# Nearest to called: and, microcebus, besieged, tao, temporal, legitimize, cebus, englishman,
# Nearest to this: which, it, the, that, kapoor, some, operatorname, each,
# Nearest to after: before, when, during, since, if, under, weak, from,
# Nearest to known: such, used, tatian, well, carnatic, just, translate, customary,
# Nearest to may: can, would, will, must, cannot, might, should, could,
# Nearest to and: or, but, upanija, agouti, wct, cebus, microcebus, operatorname,
# Nearest to have: had, has, were, are, be, johansen, abakan, cytoskeleton,
# Nearest to first: last, same, second, peacocks, thaler, carved, clo, altenberg,

# %%
### Cosine similarity makes sense, but how about DBSCAN?

# %%
# Step 6: Visualize the embeddings.
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
